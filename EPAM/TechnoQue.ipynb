# %% [markdown]
# Please prepare below areas
#
# GenAI / RAG / Evaluation
# 1. What do you understand by evaluation (eval) in Generative AI?
# 2. How do you evaluate a RAG pipeline?
# 3. What is the difference between precision and recall in RAG evaluation?
# 4. How do you measure precision?
# 5. How do you measure recall?
# 6. How do you objectively determine whether retrieval precision is high or low?
# 7. How do you evaluate RAG when a golden dataset is not available?
# 8. What role do human reviewers play in an evaluation pipeline?
# 9. How do you reduce dependency on human evaluation?
# 10. What metrics would you use to evaluate the quality of a RAG system?
# 11. How do you evaluate whether the retrieved chunks are relevant to the query?
# 12. How do you evaluate whether the final generated answer is grounded in the retrieved context?
# 13. How would you trace a RAG pipeline to identify where an incorrect answer originated?
# 14. How would you evaluate query classification in a RAG/agentic pipeline?
# 15. How would you evaluate the quality of web-search results used by an agent?
# 16. How would you evaluate SQL generated by an agent before executing it?
#
# Vector Databases
# 1. What is Milvus?
# 2. How is Milvus different from other vector databases?
# 3. What other vector databases have you worked with?
# 4. What is the difference between pgvector, Pinecone, and Milvus?
# 5. Why did you choose Milvus?
# 6. What criteria did you use to select a vector database?
# 7. Is Milvus cloud-based or can it be installed locally?
# 8. Can Milvus be used as a lightweight/file-based vector database?
# 9. How do you install Milvus?
# 10. How would you deploy Milvus using Docker?
# 11. How do you connect to Milvus from Python?
# 12. What is a collection in Milvus?
# 13. Is a Milvus collection similar to a table or a database?
# 14. How do you define a schema in Milvus?
# 15. What information needs to be defined when creating a Milvus collection?
# 16. What vector indexes does Milvus support?
# 17. What are parameters such as nprobe and ef used for?
# 18. How would you insert an embedding into Milvus?
# 19. How would you store metadata along with an embedding?
# 20. How would you update an existing vector/document in Milvus?
# 21. How would you re-ingest only one page/chunk of a PDF?
# 22. How would you identify and replace the existing vector corresponding to a specific document page?
#
# RAG / Chunking
# 1. What is chunking in a RAG pipeline?
# 2. Why is chunking required in RAG?
# 3. Why do we use chunk overlap?
# 4. How do you decide the appropriate chunk overlap?
# 5. What happens if there is no overlap between chunks?
# 6. What are the different chunking strategies you have used?
# 7. What is page-based chunking?
# 8. What is paragraph-based chunking?
# 9. What is semantic chunking?
# 10. How does semantic chunking determine whether two pieces of text are similar?
# 11. Which Python library or algorithm would you use for semantic chunking?
# 12. How would you implement semantic chunking?
# 13. How would you determine the semantic similarity between two pieces of text?
#
# Multi-Agent / LangGraph
# 1. Have you worked on a multi-agent system?
# 2. What is a multi-agent system?
# 3. How would you design a multi-agent system in LangGraph?
# 4. How would you create a query-classification node in LangGraph?
# 5. How would a query-classification node decide which tool/agent should process a request?
# 6. When would you use deterministic routing versus LLM-based routing?
# 7. How would you route a query to multiple agents?
# 8. How would you execute multiple agents in parallel?
# 9. How does LangGraph support parallel execution?
# 10. How would you use AsyncIO to execute multiple agents concurrently?
# 11. How do you define a State in LangGraph?
# 12. How do you add nodes to a LangGraph?
# 13. How do you add edges to a LangGraph?
# 14. How do you add conditional edges to a LangGraph?
# 15. How do you compile a LangGraph?
# 16. What do you pass when compiling a LangGraph?
# 17. What is checkpointing in LangGraph?
# 18. Why do we use a checkpointer?
# 19. How do you configure a PostgreSQL checkpointer?
# 20. How do you pass a checkpointer during graph compilation?
# 21. Where is checkpointing configured in a LangGraph application?
# 22. Why do you need a thread ID/session ID with LangGraph checkpointing?
# 23. How would you implement Human-in-the-Loop in LangGraph?
# 24. How do you pause a LangGraph workflow for human approval?
# 25. How do you resume a paused LangGraph workflow?
# 26. How would you persist the state when a workflow is interrupted?
# 27. How would you expose an approval mechanism/API for Human-in-the-Loop?
#
# CI/CD / GitHub Actions
# 1. Have you worked with GitHub Actions?
# 2. What is GitHub Actions?
# 3. What happens when code is pushed to GitHub?
# 4. How does a GitHub Actions workflow execute?
# 5. What checks would you perform as part of CI?
# 6. How do you configure GitHub Actions using a YAML file?
# 7. How do you manage secrets required by a CI/CD pipeline?
# 8. Where does GitHub Actions execute your workflow?
# 9. How are containers used in GitHub Actions?
# 10. What happens during a CI/CD pipeline when a code push is made?
#
# Python / Decorators
# 1. What is the difference between a generator and a decorator?
# 2. What is a Python decorator?
# 3. Can you write a decorator?
# 4. How would you write a decorator to measure the execution time of a function?
# 5. How would you make the decorator support *args and **kwargs?
# 6. How would you apply the decorator to a function?
# 7. What does the @decorator syntax mean?
#
# Python Concurrency
# 1. What is the difference between AsyncIO and multithreading?
# 2. When would you use AsyncIO?
# 3. When would you use multithreading?
# 4. When would you use multiprocessing?
# 5. How does Python's GIL affect multithreading?
# 6. Can Python execute multiple threads simultaneously?
# 7. How does multiprocessing overcome the limitations of the GIL?
# 8. How would you execute multiple independent agents concurrently?
# 9. How does the AsyncIO event loop work?
#
# Celery / Background Tasks
# 1. What is Celery?
# 2. What is a message broker?
# 3. What is the role of a message broker in Celery?
# 4. Have you used Celery?
# 5. What are FastAPI Background Tasks?
# 6. What is the difference between Celery and FastAPI BackgroundTasks?
#
# FastAPI / Scalability
# 1. What is middleware in FastAPI?
# 2. What are common use cases for FastAPI middleware?
# 3. How would you design a highly scalable FastAPI application?
# 4. How would you design a FastAPI application handling around 1 million requests per minute?
# 5. What application-level considerations would you make for high throughput?
# 6. How would you manage database connections in a high-concurrency FastAPI application?
# 7. What is connection pooling?
# 8. How does a database connection pool work?
# 9. How do you decide the appropriate connection pool size?
# 10. Why shouldn't you necessarily configure the connection pool to use the maximum number of available database connections?
# 11. How would you create a database connection from Python?
# 12. Which Python libraries can be used to connect to a database?
# 13. Have you worked with SQLAlchemy?
# 14. What is SQLAlchemy?
# 15. Why do we use SQLAlchemy?
# 16. How do you configure a database connection using SQLAlchemy?
# 17. Can SQLAlchemy manage connection pooling?
# 18. What is dependency injection in Python?
# 19. How would you use dependency injection for database connections?
#
# Database Migration / Alembic
# 1. What is Alembic?
# 2. Why do we use Alembic?
# 3. How do you handle database schema changes?
# 4. How would you rename a database column in a production application?
# 5. How would you add a new column without breaking the existing application?
# 6. Have you used Alembic in production?
#
# Cloud / AWS / Azure
# 1. Have you worked with cloud platforms?
# 2. Which AWS services have you used?
# 3. What is Amazon S3?
# 4. What is EC2?
# 5. What is Route 53?
# 6. What is AWS Secrets Manager?
# 7. Why do we use Secrets Manager?
# 8. How do you access AWS Secrets Manager from Python?
# 9. How would a Python application retrieve a secret/API key from Secrets Manager?
# 10. How do you protect secrets stored in a cloud secret manager?
# 11. How would you restrict access to secrets?
# 12. What IAM/security controls would you apply to protect sensitive credentials?
# 13. How would you secure access based on IP/network restrictions?
# 14. Which Azure services have you used?
# 15. What is Azure Cosmos DB?
# 16. Why would you use Cosmos DB?
# 17. What are the key capabilities of Cosmos DB?
#
# GenAI Security
# 1. What is prompt injection?
# 2. How can prompt injection change the behavior of an LLM?
# 3. How can prompt injection be used to extract confidential information?
# 4. How do you protect an LLM application against prompt injection?
# 5. What are guardrails?
# 6. How would you implement guardrails for an LLM connected to a database?
# 7. How would you prevent an LLM from executing unauthorized SQL queries?
# 8. How would you restrict the privileges of an agent accessing a database?
# 9. How would you protect sensitive information such as passwords and PII from being exposed by an agent?
#
# 3. What is the difference between precision and recall in RAG evaluation?
#
#
# Part 1: Evaluation + RAG (≈50 questions)
# Part 2: Vector Databases (Qdrant, Milvus, Pinecone, pgvector) + Chunking
# Part 3: Multi-Agent, LangChain, LangGraph
# Part 4: FastAPI + Python + AsyncIO + Celery
# Part 5: AWS + Azure + Docker + CI/CD
# Part 6: Security + Production + Monitoring + Failures
